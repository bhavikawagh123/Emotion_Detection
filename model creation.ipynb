# %% [markdown]
# EMOTION DETECTION

# %%
#importing libraries
import matplotlib.pyplot as plt
from glob import glob   #to create list
import cv2  # to read images
import random #to choose random numbers
import os
 #no errors while plotting below
# %matplotlib inline   

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model
from keras.callbacks import ModelCheckpoint

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:",tf.__version__ )
# Out:
# Tensorflow version: 2.16.1

# %% [markdown]
# EXPLORING DATASET

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# Data preparation for training

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
                                                    target_size = (img_size,img_size), 
                                                    color_mode = "grayscale", 
                                                    batch_size =batch_size,
                                                    class_mode = "categorical" ,
                                                    shuffle = True)
datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("test/",
                                                    target_size = (img_size,img_size), 
                                                    color_mode = "grayscale", 
                                                    batch_size =batch_size,
                                                    class_mode = "categorical" ,
                                                    shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# Defining Model

# %%
def Convolution(input_tensor,filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Dropout(0.25)(x)
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs, 32, (3,3))
    conv_2 = Convolution(inputs, 64, (5,5))
    conv_3 = Convolution(inputs, 128, (3,3))

    flatten = Flatten()(conv_3)

    dense_1 = Dense_f(flatten, 256)

    output = Dense(7,activation = "softmax")(dense_1)
    model = Model(inputs = [inputs], outputs = [output])

    model.compile(loss = ["categorical_crossentropy"], optimizer = 'adam', metrics = ['accuracy'])

    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 48, 48, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 48, 48, 128)         │           1,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 48, 48, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 48, 48, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 24, 24, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 24, 24, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 73728)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │      18,874,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │           1,799 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,879,239 (72.02 MB)
#  Trainable params: 18,878,471 (72.02 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model.weights.h5", monitor  ='val_accuracy', save_weights_only = True, mode = 'max', verbose =1)
callbacks = [checkpoint]

# %% [markdown]
# Traning the Model
# The next cell takes time to complete

# %%
history = model.fit(
x = train_generator,
steps_per_epoch = steps_per_epoch,
epochs = epochs,
validation_data = validation_generator,
validation_steps = validation_steps,
callbacks = callbacks)
# Out:
# Epoch 1/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 777ms/step - accuracy: 0.9624 - loss: 0.1227
# Epoch 1: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 362s 807ms/step - accuracy: 0.9624 - loss: 0.1227 - val_accuracy: 0.4342 - val_loss: 2.4816
# Epoch 2/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 5:53 791ms/step - accuracy: 0.9688 - loss: 0.1619
# Epoch 2: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9688 - loss: 0.1619 - val_accuracy: 0.5000 - val_loss: 2.3692
# Epoch 3/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 769ms/step - accuracy: 0.9647 - loss: 0.1127
# Epoch 3: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 357s 798ms/step - accuracy: 0.9647 - loss: 0.1127 - val_accuracy: 0.4869 - val_loss: 2.3381
# Epoch 4/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 5:31 742ms/step - accuracy: 0.9844 - loss: 0.0840
# Epoch 4: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9844 - loss: 0.0840 - val_accuracy: 0.5000 - val_loss: 2.6836
# Epoch 5/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 773ms/step - accuracy: 0.9633 - loss: 0.1150
# Epoch 5: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 359s 802ms/step - accuracy: 0.9632 - loss: 0.1150 - val_accuracy: 0.4975 - val_loss: 2.3587
# Epoch 6/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 5:36 752ms/step - accuracy: 0.9375 - loss: 0.2102
# Epoch 6: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9375 - loss: 0.2102 - val_accuracy: 0.7000 - val_loss: 2.5242
# Epoch 7/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9696 - loss: 0.1041
# Epoch 7: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 373s 831ms/step - accuracy: 0.9696 - loss: 0.1041 - val_accuracy: 0.4499 - val_loss: 2.6679
# Epoch 8/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 5:46 776ms/step - accuracy: 0.9688 - loss: 0.0561
# Epoch 8: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9688 - loss: 0.0561 - val_accuracy: 0.5000 - val_loss: 3.4896
# Epoch 9/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 778ms/step - accuracy: 0.9659 - loss: 0.1066
# Epoch 9: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 368s 821ms/step - accuracy: 0.9659 - loss: 0.1066 - val_accuracy: 0.4989 - val_loss: 2.4468
# Epoch 10/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 5:55 795ms/step - accuracy: 0.9844 - loss: 0.0513
# Epoch 10: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9844 - loss: 0.0513 - val_accuracy: 0.5000 - val_loss: 2.9753
# Epoch 11/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9697 - loss: 0.1005
# Epoch 11: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 341s 760ms/step - accuracy: 0.9697 - loss: 0.1005 - val_accuracy: 0.5006 - val_loss: 2.2390
# Epoch 12/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 5:20 716ms/step - accuracy: 0.9844 - loss: 0.0657
# Epoch 12: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9844 - loss: 0.0657 - val_accuracy: 0.4000 - val_loss: 2.1664
# Epoch 13/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 716ms/step - accuracy: 0.9700 - loss: 0.0978
# Epoch 13: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 333s 743ms/step - accuracy: 0.9699 - loss: 0.0978 - val_accuracy: 0.5010 - val_loss: 2.3047
# Epoch 14/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 5:11 698ms/step - accuracy: 0.9844 - loss: 0.0634
# Epoch 14: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9844 - loss: 0.0634 - val_accuracy: 0.5000 - val_loss: 2.4348
# Epoch 15/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 715ms/step - accuracy: 0.9730 - loss: 0.0898
# Epoch 15: saving model to model.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 333s 742ms/step - accuracy: 0.9730 - loss: 0.0898 - val_accuracy: 0.4958 - val_loss: 2.4342

# %% [markdown]
# Model Evaluation

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.4949 - loss: 2.4183
# [2.436375379562378, 0.49540260434150696]

# %% [markdown]
# Plotting Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# Saving Model

# %%
model_json = model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
